# %%
import requests
import os
from bs4 import BeautifulSoup
import itertools
import pandas
proxies = {'http': 'http://proxy.charite.de:8080',
           'https': 'https://proxy.charite.de:8080'}
print("Using HTTP proxy %s" % proxies['http'])
# Out:
# Using HTTP proxy http://proxy.charite.de:8080

# %%
# get the list
list_PIs = []
with open('PIs.txt') as fin:
    for line in fin:
        list_PIs.append(line)

# %%
# print one item of list
print(list_PIs[10])

# add a plus between name and last name
for ll in range(0,len(list_PIs)-1):
    list_PIs[ll] = list_PIs[ll].replace(' ','+')
    list_PIs[ll] = list_PIs[ll].replace('\n','')
    list_PIs[ll] = list_PIs[ll] + '[author]'
# Out:
# Nina Romanczuk-Seiferth

# %%
print(len(list_PIs))
# Out:
# 40

# %%
# make the query string
query_strings = []
for counter, ll in enumerate(list_PIs):
    query_strings.append(ll)
    
print(query_strings[30])
# Out:
# Tanja+Endrass[author]

# %%
# make th url data base query
url_queries = []

for counter, ll in enumerate(query_strings):
    url_queries.append('https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=' + ll)
    
print(url_queries[30])
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=Tanja+Endrass[author]

# %%
# call all urls and get the number of results
all_counts = []
all_papers = []
for counter, curURL in enumerate(url_queries):
    s      = requests.session()
    r      = s.get(curURL,proxies=proxies)
    soup   = BeautifulSoup(r.text,"html5lib")
    
    # get the counts
    counts = soup.find_all("count")
    all_counts.append(counts[0].get_text())
    
    # get the papers
    papers = soup.find_all("id")
    for counter, cur_paper in enumerate(papers):
        all_papers.append(papers[counter].get_text())

# %%
# check result
print(query_strings[0:5])
print(all_counts)
#print(all_papers)

#print(comb_list[0])

# get the unique joint papers
unique_papers = set(all_papers)

#print(unique_papers)

# print the number of joint publications
print(' ')
print('We have ' + str(len(unique_papers)) + ' unique publications.')
print('We have ' + str(len(all_papers)) + ' nonunique publications.')
# Out:
# ['Christine+Heim[author]', 'Andreas+Heinz[author]', 'Josef+Priller[author]', 'Florian+Schlagenhauf[author]', 'Christine+Winter[author]']
# ['101', '501', '99', '84', '118', '111', '256', '98', '151', '107', '30', '13', '59', '168', '91', '31', '206', '33', '52', '77', '12', '123', '309', '62', '482', '302', '370', '5', '57', '212', '49', '231', '79', '14', '265', '15', '42', '152', '24', '63']
#
# We have 595 joint publications.
# We have 759 nonunique publications.

# %%
# print(soup.prettify()[0:100000])
# Out:
# <!--?xml version="1.0" encoding="UTF-8" ?-->
# <!DOCTYPE esearchresult PUBLIC "-//NLM//DTD esearch 20060628//EN" "https://eutils.ncbi.nlm.nih.gov/eutils/dtd/20060628/esearch.dtd">
# <html>
#  <head>
#  </head>
#  <body>
#   <esearchresult>
#    <count>
#     50
#    </count>
#    <retmax>
#     20
#    </retmax>
#    <retstart>
#     0
#    </retstart>
#    <idlist>
#     <id>
#      30217552
#     </id>
#     <id>
#      29847018
#     </id>
#     <id>
#      29744956
#     </id>
#     <id>
#      29313106
#     </id>
#     <id>
#      29058369
#     </id>
#     <id>
#      28673442
#     </id>
#     <id>
#      28491495
#     </id>
#     <id>
#      28317230
#     </id>
#     <id>
#      27645501
#     </id>
#     <id>
#      27726253
#     </id>
#     <id>
#      27628616
#     </id>
#     <id>
#      27480622
#     </id>
#     <id>
#      27397865
#     </id>
#     <id>
#      27145766
#     </id>
#     <id>
#      27130821
#     </id>
#     <id>
#      27096667
#     </id>
#     <id>
#      26435383
#     </id>
#     <id>
#      26289945
#     </id>
#     <id>
#      26048580
#     </id>
#     <id>
#      25988224
#     </id>
#    </idlist>
#    <translationset>
#     <translation>
#      <from>
#       Andreas Heinz[author]
#      </from>
#      <to>
#       Heinz, Andreas[Full Author Name]
#      </to>
#     </translation>
#     <translation>
#      <from>
#       Anne Beck[author]
#      </from>
#      <to>
#       Beck, Anne[Full Author Name]
#      </to>
#     </translation>
#    </translationset>
#    <translationstack>
#     <termset>
#      <term>
#       Heinz, Andreas[Full Author Name]
#      </term>
#      <field>
#       Full Author Name
#      </field>
#      <count>
#       482
#      </count>
#      <explode>
#       N
#      </explode>
#     </termset>
#     <termset>
#      <term>
#       Beck, Anne[Full Author Name]
#      </term>
#      <field>
#       Full Author Name
#      </field>
#      <count>
#       105
#      </count>
#      <explode>
#       N
#      </explode>
#     </termset>
#     <op>
#      AND
#     </op>
#    </translationstack>
#    <querytranslation>
#     Heinz, Andreas[Full Author Name] AND Beck, Anne[Full Author Name]
#    </querytranslation>
#   </esearchresult>
#  </body>
# </html>

# %%
print(links[0].a["href"])
prefix = 'http://www.spielsucht-hilfe-berlin.de'
# Out:
# /shb/index.php?title=AG_Spielsucht

# %%
for element in links:
    contacts[element.a.get_text()]["link"] = prefix + element.a["href"]

# %%
for key in first_keys:
    print(key)
    print(contacts[key])
# Out:
# Netzwerk SHB
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Netzwerk_Spielsucht-Hilfe-Berlin'}
# Psychotherapeutische Praxis - Karl-Joachim Bayer
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer'}
# Vivantes Humboldt-Klinikum
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Vivantes_Humboldt-Klinikum'}
# Psychotherapeutische Praxis - Götz Saecker
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_G%C3%B6tz_Saecker'}
# Psychotherapeutische Praxis - Ulrike Sommer-Stratmann
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Ulrike_Sommer-Stratmann'}
# Psychotherapeutische Praxis - Claudia Sautier
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Claudia_Sautier'}
# Psychotherapeutische Praxis - Susanne Raetzer
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Susanne_Raetzer'}
# Glücksspiel-Sucht-Hilfe e.V.
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Gl%C3%BCcksspiel-Sucht-Hilfe_e.V.'}
# Psychotherapeutische Praxis - Sylvia Nawothnig
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Sylvia_Nawothnig'}

# %%
# now go the link and apply a function that reads out all the information
# do it with first one first
key = list(contacts.keys())[0:2][1]
#for key in first_keys:
print(key)
print(contacts[key])
# get the link
curLink = contacts[key]['link']
print(curLink)

s      = requests.session()
r      = s.get(curLink,proxies=proxies)
ssoup  = BeautifulSoup(r.text,"html5lib")
print(type(ssoup))
print(ssoup.prettify()[0:1000000])
# Out:
# Psychotherapeutische Praxis - Karl-Joachim Bayer
# {'link': 'http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer'}
# http://www.spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Psychotherapeutische Praxis - Karl-Joachim Bayer – Spielsucht-Hilfe-Berlin
#   </title>
#   <meta content="MediaWiki 1.25.2" name="generator"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/shb/opensearch_desc.php" rel="search" title="Spielsucht-Hilfe-Berlin (de)" type="application/opensearchdescription+xml"/>
#   <link href="http://spielsucht-hilfe-berlin.de/shb/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer" hreflang="x-default" rel="alternate"/>
#   <link href="/shb/index.php?title=Spezial:Letzte_%C3%84nderungen&amp;feed=atom" rel="alternate" title="Atom-Feed für „Spielsucht-Hilfe-Berlin“" type="application/atom+xml"/>
#   <link href="http://spielsucht-hilfe-berlin.de/shb/load.php?debug=false&amp;lang=de&amp;modules=mediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.content.externallinks%7Cmediawiki.skinning.interface%7Cmediawiki.ui.button%7Cskins.monobook.styles&amp;only=styles&amp;skin=monobook&amp;*" rel="stylesheet"/>
#   <!--[if IE 6]><link rel="stylesheet" href="/shb/skins/MonoBook/IE60Fixes.css?303" media="screen" /><![endif]-->
#   <!--[if IE 7]><link rel="stylesheet" href="/shb/skins/MonoBook/IE70Fixes.css?303" media="screen" /><![endif]-->
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="http://spielsucht-hilfe-berlin.de/shb/load.php?debug=false&amp;lang=de&amp;modules=site&amp;only=styles&amp;skin=monobook&amp;*" rel="stylesheet"/>
#   <style>
#    a:lang(ar),a:lang(kk-arab),a:lang(mzn),a:lang(ps),a:lang(ur){text-decoration:none}
# /* cache key: spielss_db1:resourceloader:filter:minify-css:7:126499c73021288fb0238a11305f29f9 */
#   </style>
#   <script src="http://spielsucht-hilfe-berlin.de/shb/load.php?debug=false&amp;lang=de&amp;modules=startup&amp;only=scripts&amp;skin=monobook&amp;*">
#   </script>
#   <script>
#    if(window.mw){
# mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer","wgTitle":"Psychotherapeutische Praxis - Karl-Joachim Bayer","wgCurRevisionId":457,"wgRevisionId":457,"wgArticleId":111,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Glücksspielsucht","Exzessive Internetnutzung","Erwachsene","Angehörige","Ambulante Psychotherapie","Friedrichshain-Kreuzberg"],"wgBreakFrames":false,"wgPageContentLanguage":"de","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[",\t.",".\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","Januar","Februar","März","April","Mai","Juni","Juli","August","September","Oktober","November","Dezember"],"wgMonthNamesShort":["","Jan.","Feb.","Mär.","Apr.","Mai","Jun.","Jul.","Aug.","Sep.","Okt.","Nov.","Dez."],"wgRelevantPageName":"Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer","wgRelevantArticleId":111,"wgIsProbablyEditable":false,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgWikiEditorEnabledModules":{"toolbar":false,"dialogs":false,"hidesig":true,"preview":false,"publish":false}});
# }
#   </script>
#   <script>
#    if(window.mw){
# mw.loader.implement("user.options",function($,jQuery){mw.user.options.set({"variant":"de"});});mw.loader.implement("user.tokens",function($,jQuery){mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\"});});
# /* cache key: spielss_db1:resourceloader:filter:minify-js:7:afe5a015a1f68a7615dfc51aac7ccec8 */
# }
#   </script>
#   <script>
#    if(window.mw){
# mw.loader.load(["mediawiki.page.startup","mediawiki.legacy.wikibits","mediawiki.legacy.ajax"]);
# }
#   </script>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr capitalize-all-nouns ns-0 ns-subject page-Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer skin-monobook action-view">
#   <div id="globalWrapper">
#    <div id="column-content">
#     <div class="mw-body" id="content" role="main">
#      <a id="top">
#      </a>
#      <div class="mw-indicators">
#      </div>
#      <h1 class="firstHeading" id="firstHeading" lang="de">
#       Psychotherapeutische Praxis - Karl-Joachim Bayer
#      </h1>
#      <div class="mw-body-content" id="bodyContent">
#       <div id="siteSub">
#        Aus Spielsucht-Hilfe-Berlin
#       </div>
#       <div id="contentSub">
#       </div>
#       <div class="mw-jump" id="jump-to-nav">
#        Wechseln zu:
#        <a href="#column-one">
#         Navigation
#        </a>
#        ,
#        <a href="#searchInput">
#         Suche
#        </a>
#       </div>
#       <!-- start content -->
#       <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="de">
#        <table class="wikitable" style="width:66%;">
#         <tbody>
#          <tr>
#           <th colspan="2" style="width:66%; padding:0.5em 0.4em; margin:0 0 10px 0; border:1px solid #6666cc; background:#6666cc; color:#ffffff; font-size:120%; font-weight:bold; text-align:center;">
#            Kontaktdaten
#           </th>
#           <th colspan="1" style="padding:0.5em 0.4em; margin:0 0 10px 0; border:1px solid #6666cc; background:#6666cc; color:#ffffff; font-size:120%; font-weight:bold; text-align:center;">
#            Weitere Informationen:
#           </th>
#          </tr>
#          <tr>
#           <td colspan="2" style="width:66%; font-weight:bold;">
#            Dipl.-Psych. Karl-Joachim Bayer
#           </td>
#           <td colspan="1" rowspan="10" style="padding:0.5em 0.4em; text-align:center; vertical-align:top;">
#            Psychologischer Psychotherapeut
#            <p>
#             <b>
#              Leistungen für Erwachsene bei privater Kostenübernahme:
#             </b>
#            </p>
#            <ul>
#             <li>
#              Familientherapie
#             </li>
#             <li>
#              Krisenintervention
#             </li>
#             <li>
#              Paartherapie
#             </li>
#             <li>
#              Systemische Therapie
#             </li>
#            </ul>
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2" style="padding:0.2em 0.4em; margin:0 0 10px 0; background:#cccccc; font-weight:bold;">
#            Adresse:
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2">
#            Rigaer Str. 29 b
#            <p>
#             10247 Berlin
#            </p>
#            <p>
#             <br/>
#            </p>
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2" style="padding:0.2em 0.4em; margin:0 0 10px 0; background:#cccccc; font-weight:bold;">
#            Kontakt:
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2">
#            Tel.: 030 38102323
#            <p>
#             Sprechzeiten: Nach Vereinbarung
#            </p>
#            <p>
#             E-Mail: bayer@familienzeit-berlin.de
#            </p>
#           </td>
#          </tr>
#          <tr>
#           <th colspan="2" style="padding:0.5em 0.4em; margin:0 0 10px 0; border:1px solid #6666cc; background:#6666cc; color:#ffffff; font-size:120%; font-weight:bold; text-align:center;">
#            Beratungs- und Behandlungsangebot
#           </th>
#          </tr>
#          <tr>
#           <td colspan="2" style="padding:0.2em 0.4em; margin:0 0 10px 0; background:#cccccc; font-weight:bold;">
#            Zielgruppen:
#           </td>
#          </tr>
#          <tr>
#           <td colspan="1" style="width:33%; vertical-align:top;">
#            <ul>
#             <li>
#              Glücksspielsucht
#             </li>
#             <li>
#              Exzessive Internetnutzung
#             </li>
#            </ul>
#           </td>
#           <td colspan="1" style="vertical-align:top;">
#            <ul>
#             <li>
#              Erwachsene
#             </li>
#            </ul>
#            <ul>
#             <li>
#              Angehörige
#             </li>
#            </ul>
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2" style="padding:0.2em 0.4em; margin:0 0 10px 0; background:#cccccc; font-weight:bold;">
#            Beratungs- und Behandlungsangebot:
#           </td>
#          </tr>
#          <tr>
#           <td colspan="2">
#            <ul>
#             <li>
#              ambulante Psychotherapie (Einzel)
#             </li>
#            </ul>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <!--
# NewPP limit report
# CPU time usage: 0.004 seconds
# Real time usage: 0.010 seconds
# Preprocessor visited node count: 92/1000000
# Preprocessor generated node count: 630/1000000
# Post‐expand include size: 1990/2097152 bytes
# Template argument size: 322/2097152 bytes
# Highest expansion depth: 3/40
# Expensive parser function count: 0/100
# -->
#        <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%    5.607      1 - Vorlage:Angebot
# 100.00%    5.607      1 - -total
# -->
#        <!-- Saved in parser cache with key spielss_db1:pcache:idhash:111-0!*!*!*!*!*!* and timestamp 20180522184344 and revision id 457
#  -->
#       </div>
#       <div class="printfooter">
#        Von „
#        <a dir="ltr" href="http://spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;oldid=457">
#         http://spielsucht-hilfe-berlin.de/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;oldid=457
#        </a>
#        “
#       </div>
#       <div class="catlinks" id="catlinks">
#        <div class="mw-normal-catlinks" id="mw-normal-catlinks">
#         <a href="/shb/index.php?title=Spezial:Kategorien" title="Spezial:Kategorien">
#          Kategorien
#         </a>
#         :
#         <ul>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Gl%C3%BCcksspielsucht" title="Kategorie:Glücksspielsucht">
#            Glücksspielsucht
#           </a>
#          </li>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Exzessive_Internetnutzung" title="Kategorie:Exzessive Internetnutzung">
#            Exzessive Internetnutzung
#           </a>
#          </li>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Erwachsene" title="Kategorie:Erwachsene">
#            Erwachsene
#           </a>
#          </li>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Angeh%C3%B6rige" title="Kategorie:Angehörige">
#            Angehörige
#           </a>
#          </li>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Ambulante_Psychotherapie" title="Kategorie:Ambulante Psychotherapie">
#            Ambulante Psychotherapie
#           </a>
#          </li>
#          <li>
#           <a href="/shb/index.php?title=Kategorie:Friedrichshain-Kreuzberg" title="Kategorie:Friedrichshain-Kreuzberg">
#            Friedrichshain-Kreuzberg
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <!-- end content -->
#       <div class="visualClear">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="column-one">
#     <h2>
#      Navigationsmenü
#     </h2>
#     <div class="portlet" id="p-cactions" role="navigation">
#      <h3>
#       Ansichten
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li class="selected" id="ca-nstab-main">
#         <a accesskey="c" href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer" title="Seiteninhalt anzeigen [c]">
#          Seite
#         </a>
#        </li>
#        <li class="new" id="ca-talk">
#         <a accesskey="t" href="/shb/index.php?title=Diskussion:Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;action=edit&amp;redlink=1" title="Diskussion zum Seiteninhalt [t]">
#          Diskussion
#         </a>
#        </li>
#        <li id="ca-viewsource">
#         <a accesskey="e" href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;action=edit" title="Diese Seite ist geschützt. Ihr Quelltext kann dennoch angesehen und kopiert werden. [e]">
#          Quelltext anzeigen
#         </a>
#        </li>
#        <li id="ca-history">
#         <a accesskey="h" href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;action=history" title="Frühere Versionen dieser Seite [h]">
#          Versionsgeschichte
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="portlet" id="p-personal" role="navigation">
#      <h3>
#       Meine Werkzeuge
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="pt-login">
#         <a accesskey="o" href="/shb/index.php?title=Spezial:Anmelden&amp;returnto=Psychotherapeutische+Praxis+-+Karl-Joachim+Bayer" title="Sich anzumelden wird gerne gesehen, ist jedoch nicht zwingend erforderlich. [o]">
#          Anmelden
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="portlet" id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/shb/index.php?title=Spielsucht-Hilfe-Berlin" title="Hauptseite">
#      </a>
#     </div>
#     <div class="generated-sidebar portlet" id="p-Bereich_f.C3.BCr_Betroffene" role="navigation">
#      <h3>
#       Bereich für Betroffene
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="n-Gl.C3.BCcksspielsucht">
#         <a href="/shb/index.php?title=Informationen_f%C3%BCr_Betroffene_zur_Gl%C3%BCcksspielsucht">
#          Glücksspielsucht
#         </a>
#        </li>
#        <li id="n-Exzessive-Internetnutzung">
#         <a href="/shb/index.php?title=Informationen_f%C3%BCr_Betroffene_zur_exzessiven_Internetnutzung">
#          Exzessive Internetnutzung
#         </a>
#        </li>
#        <li id="n-Beratung-und-Behandlung">
#         <a href="/shb/index.php?title=Beratung_und_Behandlung">
#          Beratung und Behandlung
#         </a>
#        </li>
#        <li id="n-Hilfe-finden.21">
#         <a href="/shb/index.php?title=Spezial:MultiCategorySearch">
#          Hilfe finden!
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="generated-sidebar portlet" id="p-Bereich_f.C3.BCr_Angeh.C3.B6rige" role="navigation">
#      <h3>
#       Bereich für Angehörige
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="n-Gl.C3.BCcksspielsucht">
#         <a href="/shb/index.php?title=Informationen_f%C3%BCr_Angeh%C3%B6rige_zur_Gl%C3%BCcksspielsucht">
#          Glücksspielsucht
#         </a>
#        </li>
#        <li id="n-Exzessive-Internetnutzung">
#         <a href="/shb/index.php?title=Informationen_f%C3%BCr_Angeh%C3%B6rige_zur_exzessiven_Internetnutzung">
#          Exzessive Internetnutzung
#         </a>
#        </li>
#        <li id="n-Beratung-und-Behandlung">
#         <a href="/shb/index.php?title=Beratung_und_Behandlung">
#          Beratung und Behandlung
#         </a>
#        </li>
#        <li id="n-Hilfe-finden.21">
#         <a href="/shb/index.php?title=Spezial:MultiCategorySearch">
#          Hilfe finden!
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="generated-sidebar portlet" id="p-Bereich_f.C3.BCr_Fachkr.C3.A4fte" role="navigation">
#      <h3>
#       Bereich für Fachkräfte
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="n-Netzwerk-SHB">
#         <a href="/shb/index.php?title=Netzwerk_Spielsucht-Hilfe-Berlin">
#          Netzwerk SHB
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="generated-sidebar portlet" id="p-Spielsucht-Hilfe-Berlin" role="navigation">
#      <h3>
#       Spielsucht-Hilfe-Berlin
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="n-Startseite">
#         <a href="/shb/index.php?title=Spielsucht-Hilfe-Berlin">
#          Startseite
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="portlet" id="p-search" role="search">
#      <h3>
#       <label for="searchInput">
#        Suche
#       </label>
#      </h3>
#      <div class="pBody" id="searchBody">
#       <form action="/shb/index.php" id="searchform">
#        <input name="title" type="hidden" value="Spezial:Suche"/>
#        <input accesskey="f" id="searchInput" name="search" placeholder="Suchen" title="Spielsucht-Hilfe-Berlin durchsuchen [f]" type="search"/>
#        <input class="searchButton" id="searchGoButton" name="go" title="Gehe direkt zu der Seite, die exakt dem eingegebenen Namen entspricht." type="submit" value="Seite"/>
#        <input class="searchButton" id="mw-searchButton" name="fulltext" title="Suche nach Seiten, die diesen Text enthalten" type="submit" value="Suchen"/>
#       </form>
#      </div>
#     </div>
#     <div class="portlet" id="p-tb" role="navigation">
#      <h3>
#       Werkzeuge
#      </h3>
#      <div class="pBody">
#       <ul>
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/shb/index.php?title=Spezial:Linkliste/Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer" title="Liste aller Seiten, die hierher verlinken [j]">
#          Links auf diese Seite
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/shb/index.php?title=Spezial:%C3%84nderungen_an_verlinkten_Seiten/Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer" title="Letzte Änderungen an Seiten, die von hier verlinkt sind [k]">
#          Änderungen an verlinkten Seiten
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/shb/index.php?title=Spezial:Spezialseiten" title="Liste aller Spezialseiten [q]">
#          Spezialseiten
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;printable=yes" rel="alternate" title="Druckansicht dieser Seite [p]">
#          Druckversion
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;oldid=457" title="Dauerhafter Link zu dieser Seitenversion">
#          Permanenter Link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/shb/index.php?title=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;action=info" title="Weitere Informationen über diese Seite">
#          Seiten­informationen
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/shb/index.php?title=Spezial:Zitierhilfe&amp;page=Psychotherapeutische_Praxis_-_Karl-Joachim_Bayer&amp;id=457" title="Hinweise, wie diese Seite zitiert werden kann">
#          Seite zitieren
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <!-- end of the left (by default at least) column -->
#    <div class="visualClear">
#    </div>
#    <div id="footer" role="contentinfo">
#     <div id="f-poweredbyico">
#      <a href="//www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/shb/resources/assets/poweredby_mediawiki_88x31.png" srcset="/shb/resources/assets/poweredby_mediawiki_132x47.png 1.5x, /shb/resources/assets/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </div>
#     <ul id="f-list">
#      <li id="lastmod">
#       Diese Seite wurde zuletzt am 31. März 2016 um 18:34 Uhr geändert.
#      </li>
#      <li id="disclaimer">
#       <a href="/shb/index.php?title=Projekt:Impressum" title="Projekt:Impressum">
#        Impressum
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script>
#    if(window.jQuery)jQuery.ready();
#   </script>
#   <script>
#    if(window.mw){
# mw.loader.state({"site":"loading","user":"ready","user.groups":"ready"});
# }
#   </script>
#   <script>
#    if(window.mw){
# mw.loader.load(["mediawiki.action.view.postEdit","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.searchSuggest"],null,true);
# }
#   </script>
#   <script>
#    if(window.mw){
# document.write("\u003Cscript src=\"http://spielsucht-hilfe-berlin.de/shb/load.php?debug=false\u0026amp;lang=de\u0026amp;modules=site\u0026amp;only=scripts\u0026amp;skin=monobook\u0026amp;*\"\u003E\u003C/script\u003E");
# }
#   </script>
#   <script>
#    if(window.mw){
# mw.config.set({"wgBackendResponseTime":167});
# }
#   </script>
#  </body>
# </html>

# %%
infos = ssoup.find_all("td")
print (type(infos))
print(len(infos))
print(infos[0:3])
# Out:
# <class 'bs4.element.ResultSet'>
# 11
# [<td colspan="2" style="width:66%; font-weight:bold;">Dipl.-Psych. Karl-Joachim Bayer
# </td>, <td colspan="1" rowspan="10" style="padding:0.5em 0.4em; text-align:center; vertical-align:top;">Psychologischer Psychotherapeut
# <p><b>Leistungen für Erwachsene bei privater Kostenübernahme:</b>
# </p>
# <ul><li>Familientherapie</li>
# <li>Krisenintervention</li>
# <li>Paartherapie</li>
# <li>Systemische Therapie</li></ul>
# </td>, <td colspan="2" style="padding:0.2em 0.4em; margin:0 0 10px 0; background:#cccccc; font-weight:bold;">Adresse:
# </td>]

# %%
infoList = {}
for element in infos:
    infoList[element.a.get_text()] = {}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-9ed7a1ee0bf6> in <module>()
#       1 infoList = {}
#       2 for element in infos:
# ----> 3     infoList[element.a.get_text()] = {}
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
